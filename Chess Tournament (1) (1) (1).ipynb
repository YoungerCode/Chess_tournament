# %%
from tkinter import *
from tkinter import ttk
from tkinter import Tk
from tkinter import messagebox
import random
from datetime import datetime
import tkinter.messagebox
import unicodedata as ud

# %%
class Tournament:
    
    def __init__(self, root):
        self.root = root
        self.root.title("Chess Profiling")
        self.root.geometry("1350x750+0+0")
        self.root.configure(background = "white")
        
        

       # background_image=root.PhotoImage( "https://pixabay.com/vectors/board-chess-chessboard-black-white-157165/")
        #background_label = root.Label(parent, image=background_image)
        #background_label.place(x=0, y=0, relwidth=1, relheight=1)
        

        
       # photo = PhotoImage(file = "/home/recruit/Desktop/chess.png")
        #w = Label(root, image=photo)
        #w.pack()
        #ent = Entry(root)
        #ent.pack()
       # ent.focus_set() 
       # root.mainloop()
        
        var1=StringVar()
        var2=StringVar()
        var3=StringVar()
        var4=StringVar()
        var5=StringVar()
        var6=StringVar()
        var7=StringVar()
        var8=StringVar()
        var9=StringVar()
     
        
        
        Username = StringVar()
        Name = StringVar()
        Cohort = StringVar()
        Numberofgamesplayed = StringVar()
        Wins = StringVar()
        Draw = StringVar()
        LevelofExperience = StringVar()
        Loose = StringVar()
        Display = StringVar()
        
        
        
        
        def iExit():
            iExit = tkinter.messagebox.askyesno ("The Pawn","Confirm if you want to exit")
            if iExit>0:
                root.destroy()
                return
            
        
        
        def iRest():
            
    
            Username.set("")
            Name.set("")
            Cohort.set("")
            Numberofgamesplayed.set("")
            Wins.set("")
            Draw.set("")
            Loose.set("")
            LevelofExperience.set("")
            Display.set("")
            self.txtDisplayR.delete("1.0", END)
            
            var1.set("")
            var2.set("")
            var3.set("")
            var4.set("")
            var5.set("")
            var6.set("")
            var7.set("")
            var8.set("")
            var9.set("")
            
        def Save():
            worrior = str(self.lblName1.get())
            display = self.txtDisplayR.insert(worrior)
            return  display
        
        
            
        
        
        def Reset():
            jReset = tkinter.messagebox.askyesno ("The Pawn","Confirm if you want to reset?")
            if jReset>0:
                iReset()
            elif jReset <=0:
                iReset()
                self.txtDisplayR.delete("1.0", END)
            
        def players(ListOfPlayers):
            
            ListOfPlayers = ['Tim', 'James', 'Sibu', 'Gloria', 'Nathi', 'Jacquar', 'Danziel', 'Dineo', 'Themba', 'Tumi', 'Senzo', 
                        'Sfiso', 'Leheto', 'Rose', 'Joe', 'Sindi', 'Velly', 'John', 'Matthew', 'Donald', 'Obama', 'Thando',
                        'Mbali', 'Pricillia', 'King', 'Keoreketswe', 'Peter', 'London', 'December']
            lst2 = random.sample(ListOfPlayers, k=2)
    
    
           # print(lst2)

        players('ListOfPlayers')

        ########################################### Frames #######################################################

        Mainframe = Frame(self.root)
        Mainframe .grid()
        
        Titleframe = Frame(Mainframe,width = 150,padx=20,bd=20,relief = RIDGE, bg= "white")
        Titleframe.pack(side = TOP)
        
        self.lblTitle = Label(Titleframe,width = 39,font = ('arial',40,'bold'),text = "\tThe Pawn\t",padx =12, bg= "white", foreground="#ff812c")
        self.lblTitle.grid()
        
        ButtonFrame = Frame(Mainframe, bd = 20, width =1350, height = 200, padx = 20, relief = RIDGE, bg= "white")
        ButtonFrame.pack(side=BOTTOM)
        
        FrameDetail = Frame(Mainframe, bd = 20, width =1350, height = 1000, padx = 20, relief = RIDGE, bg= "white")
        FrameDetail.pack(side=BOTTOM)
        
        Dataframe = Frame(Mainframe, bd = 20, width =1350, height = 100, padx = 20, relief = RIDGE, bg= "white")
        Dataframe.pack(side=BOTTOM)
        
        
        Dataframeleft = LabelFrame(Dataframe, bd = 10 ,width = 350,height = 600, padx = 20, relief=RIDGE, font=('arial', 12, 'italic', 'bold'), text = "\tPlayer Details\t", highlightbackground = "white")
        Dataframeleft.pack(side = LEFT)
        
        Dataframeright = LabelFrame(Dataframe, bd = 10 ,width = 350,height = 600, padx = 20, relief=RIDGE, font=('arial', 12, 'italic', 'bold'), text = "\tList of Players\t", fg= "black", bg= "white")
        Dataframeright.pack(side = RIGHT)
        
        
        ########################################### Widget/s ############################################################
        
        self.lblUsername = Label(Dataframeleft, font =('arial', 12, 'bold'), text = "Username: ", padx=2, pady=2, highlightbackground = 'white')
        self.lblUsername .grid(row=0, column=0, sticky=W)
        self.lblName1 = Entry(Dataframeleft, font=('arial', 12, 'bold'),textvariable = Username , width =25, bg = "white")
        self.lblName1 .grid(row=0, column=1)
        
        self.lblName = Label(Dataframeleft, font =('arial', 12, 'bold'), text = "Department: ", padx=2, pady=2)
        self.lblName .grid(row=1, column=0, sticky=W)
        self.lblName = Entry(Dataframeleft, font=('arial', 12, 'bold') , width =25, bg = "white")
        self.lblName .grid(row=1, column=1)
        
        
        self.lblCohort = Label(Dataframeleft, font =('arial', 12, 'bold'), text = "Cohort: ", padx=2, pady=2)
        self.lblCohort .grid(row=2, column=0, sticky=W)
        
        self.cboCohort = ttk.Combobox(Dataframeleft, font =('arial', 12, 'bold'), state ='readonly', textvariable = Cohort, width =23)
        self.cboCohort['value'] = ('','14', '15', '16', '17', '18', '19', '20', '21', 'Staff')
        self.cboCohort.current(0)
        self.cboCohort .grid(row=2, column=1)
        
        
        self.lblLevel = Label(Dataframeleft, font =('arial', 12, 'bold'), text = "Level of Experience: ", padx=2, pady=2)
        self.lblLevel .grid(row=3, column=0, sticky=W)
        
        self.cboLevel = ttk.Combobox(Dataframeleft, font =('arial', 12, 'bold'), state ='readonly',textvariable = LevelofExperience , width =23)
        self.cboLevel ['value'] = ('','Beginner', 'Novice', 'Master')
        self.cboLevel .current(0)
        self.cboLevel .grid(row=3, column=1)

        
        
        ###################################### List of players Widget#############################################
        #self.txtDisplayR=Text(Dataframeright,font=('arial', 12, 'bold'), width =32, height=13, padx=8, pady=20, highlightbackground = "white")
        #self.txtDisplayR.grid(row=0, column=2)
        
        #####################################List Box ###########################################################
        scrollbar = Scrollbar(Dataframeright)
        scrollbar.grid(row=0, column = 1, sticky='ns')
        
        
        ListOfPlayers = ['Tim', 'James', 'Sibu', 'Gloria', 'Nathi', 'Jacquar', 'Danziel', 'Dineo', 'Themba', 'Tumi', 'Senzo', 
                        'Sfiso', 'Leheto', 'Rose', 'Joe', 'Sindi', 'Velly', 'John', 'Matthew', 'Donald', 'Obama', 'Thando',
                        'Mbali', 'Pricillia', 'King', 'Keoreketswe', 'Peter', 'London', 'December']
        
        playerlist = Listbox(Dataframeright, width = 20, height = 12, font = ('arial', 12, 'bold'), highlightbackground = 'white', bg ='white')
        playerlist.bind('<<ListboxSelect>>')
        playerlist.grid(row=0, column =0, padx =8)
        scrollbar.config(command=playerlist.yview)
        
        for iteams in ListOfPlayers:
            playerlist.insert(END,iteams)
        #############################################Display_buttom##########################################################    
        self.lblLabel =Label(FrameDetail,font= ('arial',12,'bold'),pady=12,
        text = "Username\tName\tCohort\tNumber of games played\tWins\tDraw\tLoose\tLevel of Experience",)
        self.lblLabel.grid(row=0, column=0)
        
        self.txtDisplayR= Text(FrameDetail, font=('arial',12,'bold'),width=100, height=2,padx=2,pady=4)
        self.txtDisplayR.grid(row=1,column=0)
            
        #######################################Buttons#####################################################################################
        self.btnDisplayData=Button(ButtonFrame , text= 'Fixtures',font=('arial',12,'bold'), width=30, bd=4, bg= "#ff812c",foreground="black")
        self.btnDisplayData.grid(row=0,column=0)
        
        
        self.btnDisplayData=Button(ButtonFrame , text= 'Initiate a round',font=('arial',12,'bold'), width=30, bd=4,command = players, bg= "#ff812c")
        self.btnDisplayData.grid(row=0,column=1)
        
        self.btnDisplayData=Button(ButtonFrame , text= 'Reset',font=('arial',12,'bold'), width=30, bd=4,command =iRest, bg= "#ff812c")
        self.btnDisplayData.grid(row=0,column=2)
        
        self.btnDisplayData=Button(ButtonFrame , text= 'Exit',font=('arial',12,'bold'), width=30, bd=4,command=iExit, bg= "#ff812c")
        self.btnDisplayData.grid(row=0,column=3)
        
        self.btnDisplayData=Button(Dataframeleft, text= 'save',font=('arial',12,'bold'), width=30, bd=4,command=Save,bg= "#ff812c")
        self.btnDisplayData.grid(row=7, sticky = W)

        
        #ff812c
       
        
        
        
       
        
if __name__ == '__main__':
    root =Tk()
    application = Tournament(root)
    root.mainloop()

# %% [raw]
# def players(lst):
#
#             ListOfPlayers = ['Tim', 'James', 'Sibu', 'Gloria', 'Nathi', 'Jacquar', 'Danziel', 'Dineo', 'Themba', 'Tumi', 'Senzo',
#                         'Sfiso', 'Leheto', 'Rose', 'Joe', 'Sindi', 'Velly', 'John', 'Matthew', 'Donald', 'Obama', 'Thando',
#                         'Mbali', 'Pricillia', 'King', 'Keoreketswe', 'Peter', 'London', 'December']
#             lst2 = random.sample(ListOfPlayers, k=2)
#
#
#             print(lst2)
#
# players('ListOfPlayers')

# %%
import tkinter as tk
import random
window =tk.Tk()
window.title("get it")
window.geometry("400x400")

#------Funtions------
def phase_generator():
    
    phrases = ["The Pawn welcomes ","Welcome ","May the best player win "]
    
    name = str(entry1.get())
    
    return phrases[random.randit(0, 4)] + name 

def phrase_display():
    welcome = phase_generator()
    welcome_display = tk.Text(master=window, height =10, width= 30)
    welcome_display.grid(column = 0, row=3)
    welcome_display.insert(tk.END, welcome)
    
    

#-----LABEL--------
label1 =tk.Label(text="Welcome to my world")
label1.grid(column=0, row=0)

label2=tk.Label(text="What is your worrior name ?")
label2.grid(column=0, row=1)


#-------entry------------
Entry1 = tk.Entry()
Entry1.grid(column = 1 ,row=1)

#--------button--------
button1 = tk.Button(text ="Enter the chess Kingdom", command =  phrase_display)
button1.grid(column =0 ,row =2)


window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-77-1a118ce709e3>", line 17, in phrase_display
#     welcome = phase_generator()
#   File "<ipython-input-77-1a118ce709e3>", line 12, in phase_generator
#     name = str(entry1.get())
# NameError: name 'entry1' is not defined
